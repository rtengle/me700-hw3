# %%
from finiteelementanalysis import visualize as viz
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis import solver_demo_helper_functions as solver_demo
from finiteelementanalysis.solver import hyperelastic_solver
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This notebook will show what happens when we take the small deformation case from the Euler beam solution comparison and apply a large load to it.
#
# We will be performing mesh refinement on both D2_nn3_tri and D2_nn6_tri. The mesh will be improved until the percent chang in max deflection between refinements drops below 1%. In other words:
#
# ```math
# \frac{u^{max}_{i} - u^{max}_{i-1}}{u^{max}_{i}} < 0.01
# ```
#
# This is accomplished by simply iterating the problem over a loop.

# %%
ny =  1 # change this to refine the mesh
L = 30
H = 1
q = 500
E = 1e6
nu = 0.3
# mu = E / (2.0 * (1.0 + nu))
# kappa = E / (3.0 * (1.0 - 2.0 * nu))
mu = E / (2.0 * (1.0 + nu))
#kappa = E / (2.0 * (1.0 - nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))
material_props = np.array([mu, kappa])

for ele_type in ["D2_nn3_tri", "D2_nn6_tri"]:
    max_disp = 0
    for n in range(5):
        old_max_disp = max_disp
        nx = 5*(n+1)
        coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)
        # Identify boundaries
        boundary_nodes, boundary_edges = pre.identify_rect_boundaries(coords, connect, ele_type, 0.0, L, 0.0, H)
        # 1. Fix left boundary: both u_x and u_y = 0.
        fixed_nodes_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)
        fixed_nodes_right = pre.assign_fixed_nodes_rect(boundary_nodes, "right", 0.0, 0.0)
        fixed_nodes = np.hstack((fixed_nodes_left, fixed_nodes_right))
        # Assign distributed load on the right boundary
        dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, -q)
        # Assign artificial displacement field
        displacement = np.zeros((coords.shape))
        for kk in range(0, coords.shape[0]):
            displacement[kk, 0] = coords[kk, 0] * 0.01

        nr_num_steps = 5
        nr_print = True

        displacements_all, nr_info_all = hyperelastic_solver(material_props, ele_type, coords.T, connect.T, fixed_nodes, dload_info, nr_print, nr_num_steps, nr_tol=1e-9, nr_maxit=30)

        disp_stack = np.stack([d.reshape(-1, 2) for d in displacements_all])
        max_disp = np.max(np.abs(disp_stack))
        fname = f"large-def-{nx}-{ele_type}.gif"
        viz.make_deformation_gif(displacements_all, coords, connect, ele_type, fname)
        if (max_disp - old_max_disp)/max_disp < 0.01:
            break
# Out:
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=5.000000e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.291832e-03, Residual=8.927818e+01, tolerance=1.000000e-09
# Iteration 3, Correction=2.123620e-07, Residual=2.166444e-03, tolerance=1.000000e-09
# Iteration 4, Correction=1.941456e-15, Residual=1.033484e-10, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=4.997623e-01, Residual=5.000000e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.528476e-03, Residual=8.911865e+01, tolerance=1.000000e-09
# Iteration 3, Correction=4.834031e-06, Residual=3.252534e-03, tolerance=1.000000e-09
# Iteration 4, Correction=6.801222e-13, Residual=1.021659e-08, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=3.321021e-01, Residual=5.000000e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.838115e-03, Residual=8.791816e+01, tolerance=1.000000e-09
# Iteration 3, Correction=6.147828e-06, Residual=5.821032e-03, tolerance=1.000000e-09
# Iteration 4, Correction=2.116812e-12, Residual=3.704268e-08, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=2.474677e-01, Residual=5.000000e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.944884e-03, Residual=8.577233e+01, tolerance=1.000000e-09
# Iteration 3, Correction=6.406028e-06, Residual=9.173390e-03, tolerance=1.000000e-09
# Iteration 4, Correction=3.885565e-12, Residual=7.089246e-08, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.960947e-01, Residual=5.000000e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.940880e-03, Residual=8.283709e+01, tolerance=1.000000e-09
# Iteration 3, Correction=6.160150e-06, Residual=1.270885e-02, tolerance=1.000000e-09
# Iteration 4, Correction=5.378494e-12, Residual=1.013459e-07, tolerance=1.000000e-09
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=2.045455e+01, tolerance=1.000000e-09
# Iteration 2, Correction=2.941141e-02, Residual=4.871131e+02, tolerance=1.000000e-09
# Iteration 3, Correction=4.571681e-03, Residual=7.351769e-01, tolerance=1.000000e-09
# Iteration 4, Correction=3.250419e-06, Residual=1.095502e-02, tolerance=1.000000e-09
# Iteration 5, Correction=1.284416e-11, Residual=5.764135e-09, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=4.835241e-01, Residual=2.045455e+01, tolerance=1.000000e-09
# Iteration 2, Correction=4.269245e-02, Residual=3.968024e+02, tolerance=1.000000e-09
# Iteration 3, Correction=4.853220e-03, Residual=3.513205e+00, tolerance=1.000000e-09
# Iteration 4, Correction=1.132848e-05, Residual=4.245939e-02, tolerance=1.000000e-09
# Iteration 5, Correction=1.651195e-10, Residual=2.371710e-07, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=2.918578e-01, Residual=2.045455e+01, tolerance=1.000000e-09
# Iteration 2, Correction=2.718324e-02, Residual=2.576885e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.750102e-03, Residual=2.593400e+00, tolerance=1.000000e-09
# Iteration 4, Correction=2.284863e-06, Residual=1.044451e-02, tolerance=1.000000e-09
# Iteration 5, Correction=7.393231e-12, Residual=1.832585e-08, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=1.971469e-01, Residual=2.045455e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.604779e-02, Residual=1.687270e+02, tolerance=1.000000e-09
# Iteration 3, Correction=5.918821e-04, Residual=1.345344e+00, tolerance=1.000000e-09
# Iteration 4, Correction=3.242608e-07, Residual=1.797823e-03, tolerance=1.000000e-09
# Iteration 5, Correction=1.616850e-13, Residual=5.685508e-10, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.446259e-01, Residual=2.045455e+01, tolerance=1.000000e-09
# Iteration 2, Correction=9.944417e-03, Residual=1.178273e+02, tolerance=1.000000e-09
# Iteration 3, Correction=2.262270e-04, Residual=6.903429e-01, tolerance=1.000000e-09
# Iteration 4, Correction=5.358877e-08, Residual=3.524276e-04, tolerance=1.000000e-09
# Iteration 5, Correction=4.693961e-15, Residual=3.968687e-11, tolerance=1.000000e-09
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=1.169268e+01, tolerance=1.000000e-09
# Iteration 2, Correction=8.588267e-02, Residual=8.089186e+02, tolerance=1.000000e-09
# Iteration 3, Correction=5.185952e-02, Residual=7.190962e+00, tolerance=1.000000e-09
# Iteration 4, Correction=1.186142e-03, Residual=1.936543e+00, tolerance=1.000000e-09
# Iteration 5, Correction=2.183793e-06, Residual=1.015004e-03, tolerance=1.000000e-09
# Iteration 6, Correction=3.300412e-12, Residual=3.523829e-09, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=4.445478e-01, Residual=1.169268e+01, tolerance=1.000000e-09
# Iteration 2, Correction=7.217923e-02, Residual=3.860152e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.590542e-02, Residual=1.054919e+01, tolerance=1.000000e-09
# Iteration 4, Correction=2.274994e-04, Residual=5.006912e-01, tolerance=1.000000e-09
# Iteration 5, Correction=8.612784e-08, Residual=1.042725e-04, tolerance=1.000000e-09
# Iteration 6, Correction=1.063736e-14, Residual=2.214492e-11, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=2.459888e-01, Residual=1.169268e+01, tolerance=1.000000e-09
# Iteration 2, Correction=3.059428e-02, Residual=1.690963e+02, tolerance=1.000000e-09
# Iteration 3, Correction=2.402462e-03, Residual=2.988607e+00, tolerance=1.000000e-09
# Iteration 4, Correction=6.485920e-06, Residual=1.876574e-02, tolerance=1.000000e-09
# Iteration 5, Correction=7.397259e-11, Residual=1.413786e-07, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=1.627779e-01, Residual=1.169268e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.519700e-02, Residual=9.676635e+01, tolerance=1.000000e-09
# Iteration 3, Correction=5.693754e-04, Residual=1.009035e+00, tolerance=1.000000e-09
# Iteration 4, Correction=4.013161e-07, Residual=1.459420e-03, tolerance=1.000000e-09
# Iteration 5, Correction=2.955836e-13, Residual=7.514276e-10, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.199073e-01, Residual=1.169268e+01, tolerance=1.000000e-09
# Iteration 2, Correction=8.786885e-03, Residual=6.474080e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.887978e-04, Residual=4.265532e-01, tolerance=1.000000e-09
# Iteration 4, Correction=4.651105e-08, Residual=2.050436e-04, tolerance=1.000000e-09
# Iteration 5, Correction=4.568887e-15, Residual=2.455775e-11, tolerance=1.000000e-09
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=7.783748e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.177928e-01, Residual=9.289637e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.214615e-01, Residual=1.420408e+01, tolerance=1.000000e-09
# Iteration 4, Correction=9.658691e-03, Residual=1.029370e+01, tolerance=1.000000e-09
# Iteration 5, Correction=1.614633e-04, Residual=6.303821e-02, tolerance=1.000000e-09
# Iteration 6, Correction=2.506784e-08, Residual=1.837541e-05, tolerance=1.000000e-09
# Iteration 7, Correction=3.226967e-15, Residual=8.225425e-12, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=4.150046e-01, Residual=7.783748e+00, tolerance=1.000000e-09
# Iteration 2, Correction=7.634804e-02, Residual=2.794389e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.829026e-02, Residual=9.661088e+00, tolerance=1.000000e-09
# Iteration 4, Correction=3.579602e-04, Residual=5.571763e-01, tolerance=1.000000e-09
# Iteration 5, Correction=2.345211e-07, Residual=2.172362e-04, tolerance=1.000000e-09
# Iteration 6, Correction=7.692870e-14, Residual=1.032444e-10, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=2.250290e-01, Residual=7.783748e+00, tolerance=1.000000e-09
# Iteration 2, Correction=2.892445e-02, Residual=1.099588e+02, tolerance=1.000000e-09
# Iteration 3, Correction=2.191774e-03, Residual=2.065030e+00, tolerance=1.000000e-09
# Iteration 4, Correction=5.992052e-06, Residual=1.249552e-02, tolerance=1.000000e-09
# Iteration 5, Correction=6.816510e-11, Residual=9.625228e-08, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=1.498203e-01, Residual=7.783748e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.404724e-02, Residual=6.240149e+01, tolerance=1.000000e-09
# Iteration 3, Correction=4.985065e-04, Residual=6.489492e-01, tolerance=1.000000e-09
# Iteration 4, Correction=3.311212e-07, Residual=8.817286e-04, tolerance=1.000000e-09
# Iteration 5, Correction=2.154537e-13, Residual=4.036246e-10, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.112883e-01, Residual=7.783748e+00, tolerance=1.000000e-09
# Iteration 2, Correction=8.108541e-03, Residual=4.197620e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.652714e-04, Residual=2.696068e-01, tolerance=1.000000e-09
# Iteration 4, Correction=3.785363e-08, Residual=1.238942e-04, tolerance=1.000000e-09
# Iteration 5, Correction=3.638125e-15, Residual=2.427086e-11, tolerance=1.000000e-09
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=5.652669e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.335233e-01, Residual=9.193235e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.736396e-01, Residual=1.747257e+01, tolerance=1.000000e-09
# Iteration 4, Correction=2.384674e-02, Residual=1.875396e+01, tolerance=1.000000e-09
# Iteration 5, Correction=1.046977e-03, Residual=3.291089e-01, tolerance=1.000000e-09
# Iteration 6, Correction=1.208372e-06, Residual=6.695037e-04, tolerance=1.000000e-09
# Iteration 7, Correction=2.180369e-12, Residual=8.805215e-10, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=3.977362e-01, Residual=5.652669e+00, tolerance=1.000000e-09
# Iteration 2, Correction=7.599549e-02, Residual=2.044474e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.819988e-02, Residual=7.594454e+00, tolerance=1.000000e-09
# Iteration 4, Correction=3.798408e-04, Residual=4.469319e-01, tolerance=1.000000e-09
# Iteration 5, Correction=2.760498e-07, Residual=1.980888e-04, tolerance=1.000000e-09
# Iteration 6, Correction=1.142495e-13, Residual=1.112722e-10, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=2.149856e-01, Residual=5.652669e+00, tolerance=1.000000e-09
# Iteration 2, Correction=2.775627e-02, Residual=7.831962e+01, tolerance=1.000000e-09
# Iteration 3, Correction=2.038199e-03, Residual=1.474838e+00, tolerance=1.000000e-09
# Iteration 4, Correction=5.400559e-06, Residual=8.619298e-03, tolerance=1.000000e-09
# Iteration 5, Correction=5.767975e-11, Residual=6.207621e-08, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=1.438856e-01, Residual=5.652669e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.344445e-02, Residual=4.462004e+01, tolerance=1.000000e-09
# Iteration 3, Correction=4.630712e-04, Residual=4.567971e-01, tolerance=1.000000e-09
# Iteration 4, Correction=2.951186e-07, Residual=6.084270e-04, tolerance=1.000000e-09
# Iteration 5, Correction=1.802648e-13, Residual=2.526412e-10, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.073797e-01, Residual=5.652669e+00, tolerance=1.000000e-09
# Iteration 2, Correction=7.781197e-03, Residual=3.016454e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.547292e-04, Residual=1.900594e-01, tolerance=1.000000e-09
# Iteration 4, Correction=3.422251e-08, Residual=8.744305e-05, tolerance=1.000000e-09
# Iteration 5, Correction=2.869771e-15, Residual=1.216971e-11, tolerance=1.000000e-09
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=1.749636e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.572926e-01, Residual=5.818344e+03, tolerance=1.000000e-09
# Iteration 3, Correction=3.098122e-01, Residual=1.642796e+02, tolerance=1.000000e-09
# Iteration 4, Correction=1.076193e-01, Residual=2.712967e+02, tolerance=1.000000e-09
# Iteration 5, Correction=2.442165e-02, Residual=2.603244e+01, tolerance=1.000000e-09
# Iteration 6, Correction=7.738228e-04, Residual=1.278482e+00, tolerance=1.000000e-09
# Iteration 7, Correction=9.652920e-07, Residual=1.278367e-03, tolerance=1.000000e-09
# Iteration 8, Correction=1.329026e-12, Residual=1.977363e-09, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=3.580075e-01, Residual=1.749636e+01, tolerance=1.000000e-09
# Iteration 2, Correction=7.038323e-02, Residual=5.681276e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.656222e-02, Residual=2.255231e+01, tolerance=1.000000e-09
# Iteration 4, Correction=3.467084e-04, Residual=1.214688e+00, tolerance=1.000000e-09
# Iteration 5, Correction=2.417988e-07, Residual=5.321136e-04, tolerance=1.000000e-09
# Iteration 6, Correction=9.113500e-14, Residual=2.886063e-10, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=1.949977e-01, Residual=1.749636e+01, tolerance=1.000000e-09
# Iteration 2, Correction=2.470111e-02, Residual=2.112992e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.748015e-03, Residual=3.904853e+00, tolerance=1.000000e-09
# Iteration 4, Correction=4.310553e-06, Residual=2.032530e-02, tolerance=1.000000e-09
# Iteration 5, Correction=3.908754e-11, Residual=1.243337e-07, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=1.326221e-01, Residual=1.749636e+01, tolerance=1.000000e-09
# Iteration 2, Correction=1.199580e-02, Residual=1.204642e+02, tolerance=1.000000e-09
# Iteration 3, Correction=3.999538e-04, Residual=1.195397e+00, tolerance=1.000000e-09
# Iteration 4, Correction=2.391611e-07, Residual=1.421788e-03, tolerance=1.000000e-09
# Iteration 5, Correction=1.260612e-13, Residual=5.485914e-10, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=1.002806e-01, Residual=1.749636e+01, tolerance=1.000000e-09
# Iteration 2, Correction=6.990133e-03, Residual=8.159219e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.347938e-04, Residual=4.974972e-01, tolerance=1.000000e-09
# Iteration 4, Correction=2.823658e-08, Residual=2.022971e-04, tolerance=1.000000e-09
# Iteration 5, Correction=2.781219e-15, Residual=9.244248e-11, tolerance=1.000000e-09
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=6.603774e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.723499e-01, Residual=2.968582e+03, tolerance=1.000000e-09
# Iteration 3, Correction=3.327281e-01, Residual=9.206237e+01, tolerance=1.000000e-09
# Iteration 4, Correction=1.379062e-01, Residual=1.681398e+02, tolerance=1.000000e-09
# Iteration 5, Correction=4.556025e-02, Residual=2.090901e+01, tolerance=1.000000e-09
# Iteration 6, Correction=3.066246e-03, Residual=2.341582e+00, tolerance=1.000000e-09
# Iteration 7, Correction=1.755267e-05, Residual=1.033111e-02, tolerance=1.000000e-09
# Iteration 8, Correction=5.109958e-10, Residual=3.569403e-07, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=3.491198e-01, Residual=6.603774e+00, tolerance=1.000000e-09
# Iteration 2, Correction=6.923231e-02, Residual=2.263082e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.534550e-02, Residual=8.952248e+00, tolerance=1.000000e-09
# Iteration 4, Correction=3.080710e-04, Residual=4.882463e-01, tolerance=1.000000e-09
# Iteration 5, Correction=2.045017e-07, Residual=1.976662e-04, tolerance=1.000000e-09
# Iteration 6, Correction=7.174985e-14, Residual=1.151964e-10, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=1.909134e-01, Residual=6.603774e+00, tolerance=1.000000e-09
# Iteration 2, Correction=2.433294e-02, Residual=8.650125e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.653300e-03, Residual=1.558617e+00, tolerance=1.000000e-09
# Iteration 4, Correction=3.911124e-06, Residual=8.777625e-03, tolerance=1.000000e-09
# Iteration 5, Correction=3.537106e-11, Residual=5.052503e-08, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=1.300000e-01, Residual=6.603774e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.190073e-02, Residual=5.005771e+01, tolerance=1.000000e-09
# Iteration 3, Correction=3.885695e-04, Residual=4.873623e-01, tolerance=1.000000e-09
# Iteration 4, Correction=2.293517e-07, Residual=6.759679e-04, tolerance=1.000000e-09
# Iteration 5, Correction=1.331124e-13, Residual=2.721432e-10, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=9.826229e-02, Residual=6.603774e+00, tolerance=1.000000e-09
# Iteration 2, Correction=6.969237e-03, Residual=3.413221e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.337250e-04, Residual=2.067063e-01, tolerance=1.000000e-09
# Iteration 4, Correction=2.851635e-08, Residual=1.041783e-04, tolerance=1.000000e-09
# Iteration 5, Correction=2.663999e-15, Residual=8.685423e-11, tolerance=1.000000e-09
# Step 0, load factor = 0.200
# Iteration 1, Correction=1.000000e+00, Residual=3.676207e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.750271e-01, Residual=1.734534e+03, tolerance=1.000000e-09
# Iteration 3, Correction=3.363363e-01, Residual=5.499832e+01, tolerance=1.000000e-09
# Iteration 4, Correction=1.429248e-01, Residual=1.006432e+02, tolerance=1.000000e-09
# Iteration 5, Correction=4.967842e-02, Residual=1.298464e+01, tolerance=1.000000e-09
# Iteration 6, Correction=3.705012e-03, Residual=1.628520e+00, tolerance=1.000000e-09
# Iteration 7, Correction=2.611933e-05, Residual=8.792544e-03, tolerance=1.000000e-09
# Iteration 8, Correction=1.154507e-09, Residual=4.669825e-07, tolerance=1.000000e-09
# Iteration 9, Correction=1.117465e-15, Residual=2.500447e-11, tolerance=1.000000e-09
# Step 1, load factor = 0.400
# Iteration 1, Correction=3.476937e-01, Residual=3.676207e+00, tolerance=1.000000e-09
# Iteration 2, Correction=6.901679e-02, Residual=1.274736e+02, tolerance=1.000000e-09
# Iteration 3, Correction=1.516851e-02, Residual=5.011915e+00, tolerance=1.000000e-09
# Iteration 4, Correction=3.025818e-04, Residual=2.770011e-01, tolerance=1.000000e-09
# Iteration 5, Correction=2.004563e-07, Residual=1.105338e-04, tolerance=1.000000e-09
# Iteration 6, Correction=7.040405e-14, Residual=7.127997e-11, tolerance=1.000000e-09
# Step 2, load factor = 0.600
# Iteration 1, Correction=1.902579e-01, Residual=3.676207e+00, tolerance=1.000000e-09
# Iteration 2, Correction=2.426714e-02, Residual=4.908754e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.640645e-03, Residual=8.755258e-01, tolerance=1.000000e-09
# Iteration 4, Correction=3.882856e-06, Residual=5.130615e-03, tolerance=1.000000e-09
# Iteration 5, Correction=3.612949e-11, Residual=2.981682e-08, tolerance=1.000000e-09
# Step 3, load factor = 0.800
# Iteration 1, Correction=1.295803e-01, Residual=3.676207e+00, tolerance=1.000000e-09
# Iteration 2, Correction=1.188290e-02, Residual=2.852022e+01, tolerance=1.000000e-09
# Iteration 3, Correction=3.868384e-04, Residual=2.751990e-01, tolerance=1.000000e-09
# Iteration 4, Correction=2.301611e-07, Residual=4.045170e-04, tolerance=1.000000e-09
# Iteration 5, Correction=1.414755e-13, Residual=1.595994e-10, tolerance=1.000000e-09
# Step 4, load factor = 1.000
# Iteration 1, Correction=9.794068e-02, Residual=3.676207e+00, tolerance=1.000000e-09
# Iteration 2, Correction=6.964985e-03, Residual=1.948842e+01, tolerance=1.000000e-09
# Iteration 3, Correction=1.333829e-04, Residual=1.172093e-01, tolerance=1.000000e-09
# Iteration 4, Correction=2.882693e-08, Residual=6.330248e-05, tolerance=1.000000e-09
# Iteration 5, Correction=2.734708e-15, Residual=4.646322e-11, tolerance=1.000000e-09

# %% [markdown]
# ![alt text](large-def-5-D2_nn3_tri.gif)
# ![alt text](large-def-10-D2_nn3_tri.gif)
# ![alt text](large-def-15-D2_nn3_tri.gif)
# ![alt text](large-def-20-D2_nn3_tri.gif)
# ![alt text](large-def-25-D2_nn3_tri.gif)
# ![alt text](large-def-5-D2_nn6_tri.gif)
# ![alt text](large-def-10-D2_nn6_tri.gif)
# ![alt text](large-def-15-D2_nn6_tri.gif)

# %% [markdown]
# The mesh refinement process iterated on D2_nn3_tri until there were 25 horizontal elements while on D2_nn6_tri it iterated until there were 15 elements. It's very clear that D2_nn6_tri provides a more accurate element, reducing the element by 10 or by 3/5. However, it could be bounded by the fact that even 25 elements on the beam is enough that further increases in mesh size might not be necessary.
