# %%
from finiteelementanalysis import visualize as viz
from finiteelementanalysis import pre_process as pre
from finiteelementanalysis import pre_process_demo_helper_fcns as pre_demo
from finiteelementanalysis import solver_demo_helper_functions as solver_demo
from finiteelementanalysis.solver import hyperelastic_solver
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This notebook will show what happens when we take the small deformation case from the Euler beam solution comparison and apply a large load to it.
#
# We will be using D2_nn6_tri with 100 horizontal elements and 2 vertical elements. Our beam is represented by a 30 x 1 rectangle.

# %%
ele_type = "D2_nn6_tri" # change this!
nx = 100 # change this to refine the mesh
ny = 3 # change this to refine the mesh
L = 30
H = 1

coords, connect = pre.generate_rect_mesh_2d(ele_type, 0.0, 0.0, L, H, nx, ny)

# %% [markdown]
# Our problem will have a distributed downward load on the top with both left and right ends fixed. Our load and material properties are defined below.

# %%
# Identify boundaries
boundary_nodes, boundary_edges = pre.identify_rect_boundaries(coords, connect, ele_type, 0.0, L, 0.0, H)
# 1. Fix left boundary: both u_x and u_y = 0.
fixed_nodes_left = pre.assign_fixed_nodes_rect(boundary_nodes, "left", 0.0, 0.0)
fixed_nodes_right = pre.assign_fixed_nodes_rect(boundary_nodes, "right", 0.0, 0.0)
fixed_nodes = np.hstack((fixed_nodes_left, fixed_nodes_right))
# Assign distributed load on the right boundary
q = 500
dload_info = pre.assign_uniform_load_rect(boundary_edges, "top", 0.0, -q)
# Assign material properties
E = 1e6
nu = 0.3
# mu = E / (2.0 * (1.0 + nu))
# kappa = E / (3.0 * (1.0 - 2.0 * nu))
mu = E / (2.0 * (1.0 + nu))
#kappa = E / (2.0 * (1.0 - nu))
kappa = E / (3.0 * (1.0 - 2.0 * nu))
material_props = np.array([mu, kappa])
# Assign artificial displacement field
displacement = np.zeros((coords.shape))
for kk in range(0, coords.shape[0]):
    displacement[kk, 0] = coords[kk, 0] * 0.01

# Analytical solution
def solution(x, load_factor):
    w = q*load_factor
    I = H**3/12
    y = 0.5 - w * x**2 / (24*E*I) * (L-x)**2
    return y

# Animated plot
fname = "hw_solver_large_deformation.png"
pre_demo.plot_mesh_2D(fname, ele_type, coords, connect)

# %% [markdown]
# We now run the hyperelastic solver over 20 steps and animate the result:

# %%
# run the example to look at the results

nr_num_steps = 20
nr_print = True

displacements_all, nr_info_all = hyperelastic_solver(material_props, ele_type, coords.T, connect.T, fixed_nodes, dload_info, nr_print, nr_num_steps, nr_tol=1e-9, nr_maxit=30)

fname = "large-def.gif"
viz.make_deformation_gif(solution, displacements_all, coords, connect, ele_type, fname)
# Out:
# Step 0, load factor = 0.050
# Iteration 1, Correction=1.000000e+00, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=9.683046e-02, Residual=2.545223e+00, tolerance=1.000000e-09
# Iteration 3, Correction=7.110130e-02, Residual=2.364541e-02, tolerance=1.000000e-09
# Iteration 4, Correction=2.493006e-03, Residual=1.090010e-02, tolerance=1.000000e-09
# Iteration 5, Correction=1.016664e-05, Residual=1.304786e-05, tolerance=1.000000e-09
# Iteration 6, Correction=7.930774e-11, Residual=2.286522e-10, tolerance=1.000000e-09
# Step 1, load factor = 0.100
# Iteration 1, Correction=4.351515e-01, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=7.486384e-02, Residual=1.057301e+00, tolerance=1.000000e-09
# Iteration 3, Correction=1.721942e-02, Residual=3.043061e-02, tolerance=1.000000e-09
# Iteration 4, Correction=2.814437e-04, Residual=1.674244e-03, tolerance=1.000000e-09
# Iteration 5, Correction=1.369727e-07, Residual=4.486116e-07, tolerance=1.000000e-09
# Iteration 6, Correction=2.389884e-14, Residual=1.803106e-12, tolerance=1.000000e-09
# Step 2, load factor = 0.150
# Iteration 1, Correction=2.380524e-01, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=3.051053e-02, Residual=4.429902e-01, tolerance=1.000000e-09
# Iteration 3, Correction=2.382648e-03, Residual=7.807339e-03, tolerance=1.000000e-09
# Iteration 4, Correction=6.576262e-06, Residual=5.143392e-05, tolerance=1.000000e-09
# Iteration 5, Correction=7.837030e-11, Residual=3.997379e-10, tolerance=1.000000e-09
# Step 3, load factor = 0.200
# Iteration 1, Correction=1.572264e-01, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=1.502934e-02, Residual=2.516940e-01, tolerance=1.000000e-09
# Iteration 3, Correction=5.541903e-04, Residual=2.546354e-03, tolerance=1.000000e-09
# Iteration 4, Correction=3.872334e-07, Residual=3.815955e-06, tolerance=1.000000e-09
# Iteration 5, Correction=2.822868e-13, Residual=3.568856e-12, tolerance=1.000000e-09
# Step 4, load factor = 0.250
# Iteration 1, Correction=1.157715e-01, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=8.687072e-03, Residual=1.683163e-01, tolerance=1.000000e-09
# Iteration 3, Correction=1.834037e-04, Residual=1.060191e-03, tolerance=1.000000e-09
# Iteration 4, Correction=4.442064e-08, Residual=5.328307e-07, tolerance=1.000000e-09
# Iteration 5, Correction=3.631023e-15, Residual=3.439605e-12, tolerance=1.000000e-09
# Step 5, load factor = 0.300
# Iteration 1, Correction=9.106050e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=5.590767e-03, Residual=1.236061e-01, tolerance=1.000000e-09
# Iteration 3, Correction=7.605203e-05, Residual=5.234836e-04, tolerance=1.000000e-09
# Iteration 4, Correction=7.878064e-09, Residual=1.120341e-07, tolerance=1.000000e-09
# Iteration 5, Correction=5.251293e-16, Residual=3.571981e-12, tolerance=1.000000e-09
# Step 6, load factor = 0.350
# Iteration 1, Correction=7.480262e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=3.875218e-03, Residual=9.632614e-02, tolerance=1.000000e-09
# Iteration 3, Correction=3.673289e-05, Residual=2.913110e-04, tolerance=1.000000e-09
# Iteration 4, Correction=1.882228e-09, Residual=3.108688e-08, tolerance=1.000000e-09
# Iteration 5, Correction=1.880524e-16, Residual=3.455213e-12, tolerance=1.000000e-09
# Step 7, load factor = 0.400
# Iteration 1, Correction=6.335023e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=2.833996e-03, Residual=7.817830e-02, tolerance=1.000000e-09
# Iteration 3, Correction=1.978265e-05, Residual=1.768393e-04, tolerance=1.000000e-09
# Iteration 4, Correction=5.570920e-10, Residual=1.050943e-08, tolerance=1.000000e-09
# Step 8, load factor = 0.450
# Iteration 1, Correction=5.487220e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=2.157731e-03, Residual=6.534118e-02, tolerance=1.000000e-09
# Iteration 3, Correction=1.155509e-05, Residual=1.146187e-04, tolerance=1.000000e-09
# Iteration 4, Correction=1.935558e-10, Residual=4.113782e-09, tolerance=1.000000e-09
# Step 9, load factor = 0.500
# Iteration 1, Correction=4.835565e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=1.695040e-03, Residual=5.583671e-02, tolerance=1.000000e-09
# Iteration 3, Correction=7.185917e-06, Residual=7.816769e-05, tolerance=1.000000e-09
# Iteration 4, Correction=7.612963e-11, Residual=1.802098e-09, tolerance=1.000000e-09
# Step 10, load factor = 0.550
# Iteration 1, Correction=4.319742e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=1.365193e-03, Residual=4.854796e-02, tolerance=1.000000e-09
# Iteration 3, Correction=4.696758e-06, Residual=5.551281e-05, tolerance=1.000000e-09
# Iteration 4, Correction=3.304471e-11, Residual=8.627621e-10, tolerance=1.000000e-09
# Step 11, load factor = 0.600
# Iteration 1, Correction=3.901704e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=1.122113e-03, Residual=4.280052e-02, tolerance=1.000000e-09
# Iteration 3, Correction=3.196393e-06, Residual=4.074444e-05, tolerance=1.000000e-09
# Iteration 4, Correction=1.553861e-11, Residual=4.437769e-10, tolerance=1.000000e-09
# Step 12, load factor = 0.650
# Iteration 1, Correction=3.556311e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=9.380078e-04, Residual=3.816491e-02, tolerance=1.000000e-09
# Iteration 3, Correction=2.249269e-06, Residual=3.073195e-05, tolerance=1.000000e-09
# Iteration 4, Correction=7.807026e-12, Residual=2.421122e-10, tolerance=1.000000e-09
# Step 13, load factor = 0.700
# Iteration 1, Correction=3.266310e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=7.953387e-04, Residual=3.435557e-02, tolerance=1.000000e-09
# Iteration 3, Correction=1.627905e-06, Residual=2.371755e-05, tolerance=1.000000e-09
# Iteration 4, Correction=4.146723e-12, Residual=1.388832e-10, tolerance=1.000000e-09
# Step 14, load factor = 0.750
# Iteration 1, Correction=3.019479e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=6.826086e-04, Residual=3.117572e-02, tolerance=1.000000e-09
# Iteration 3, Correction=1.206752e-06, Residual=1.866508e-05, tolerance=1.000000e-09
# Iteration 4, Correction=2.309221e-12, Residual=8.311079e-11, tolerance=1.000000e-09
# Step 15, load factor = 0.800
# Iteration 1, Correction=2.806928e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=5.920332e-04, Residual=2.848563e-02, tolerance=1.000000e-09
# Iteration 3, Correction=9.132164e-07, Residual=1.493806e-05, tolerance=1.000000e-09
# Iteration 4, Correction=1.339781e-12, Residual=5.162652e-11, tolerance=1.000000e-09
# Step 16, load factor = 0.850
# Iteration 1, Correction=2.622037e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=5.181945e-04, Residual=2.618352e-02, tolerance=1.000000e-09
# Iteration 3, Correction=7.036185e-07, Residual=1.213146e-05, tolerance=1.000000e-09
# Iteration 4, Correction=8.051133e-13, Residual=3.334164e-11, tolerance=1.000000e-09
# Step 17, load factor = 0.900
# Iteration 1, Correction=2.459778e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=4.572293e-04, Residual=2.419357e-02, tolerance=1.000000e-09
# Iteration 3, Correction=5.507573e-07, Residual=9.979500e-06, tolerance=1.000000e-09
# Iteration 4, Correction=4.989221e-13, Residual=2.232298e-11, tolerance=1.000000e-09
# Step 18, load factor = 0.950
# Iteration 1, Correction=2.316268e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=4.063244e-04, Residual=2.245824e-02, tolerance=1.000000e-09
# Iteration 3, Correction=4.371763e-07, Residual=8.303028e-06, tolerance=1.000000e-09
# Iteration 4, Correction=3.182024e-13, Residual=1.579714e-11, tolerance=1.000000e-09
# Step 19, load factor = 1.000
# Iteration 1, Correction=2.188459e-02, Residual=1.984569e-02, tolerance=1.000000e-09
# Iteration 2, Correction=3.633925e-04, Residual=2.093312e-02, tolerance=1.000000e-09
# Iteration 3, Correction=3.513723e-07, Residual=6.978414e-06, tolerance=1.000000e-09
# Iteration 4, Correction=2.077603e-13, Residual=1.178416e-11, tolerance=1.000000e-09

# %%
# Get the final displacements and new positions
final_disp = displacements_all[-1].reshape(-1, 2)
pos = coords + final_disp

# Plot the error
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(pos[:, 0], final_disp[:, 1] - (solution(pos[:, 0], 1) - 0.5))
ax.set_xlabel('x position')
ax.set_ylabel('Displacement error')
ax.set_title('Difference Between Slender Beam Solution & Numeric Solution')
plt.savefig('large-deformation-diff.png', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.close(fig)
